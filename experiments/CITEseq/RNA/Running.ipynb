# %%
from matplotlib import pyplot as plt
from pyppca import ppca
from sklearn import mixture
from sklearn.cluster import SpectralClustering
from operator import itemgetter
import os
from sklearn.decomposition import PCA
import numpy as np
import pickle
import sys
import pandas as pd
import scanpy as sc
from sklearn.metrics import *
data_folder_path = '../../../data'
sys.path.append(data_folder_path)
import matplotlib.patches as mpatches
import anndata as ad
from sklearn.neighbors import NearestNeighbors
import tensorflow as tf
import gpflow
float_type = gpflow.default_float()
import gpflux
from gpflow.config import default_float
from tensorflow.keras.layers import Input, Dense, Flatten, Concatenate, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import muon as mu
from muon import atac as ac
from muon import prot as pt
sys.path.append('../../../mogp_decomposition/')
import mwgp as mwgp
from mwgp import GPD
import glob
from evaluation import *

def get_free_gpu_idx():
    """Get the index of the GPU with current lowest memory usage."""
    os.system("nvidia-smi -q -d Memory |grep -A4 GPU|grep Used >tmp")
    memory_available = [int(x.split()[2]) for x in open("tmp", "r").readlines()]
    return np.argmin(memory_available)

gpu_idx = get_free_gpu_idx()
print("Using GPU #%s" % gpu_idx)
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_idx)
# Out:
# 2024-06-10 19:08:11.017690: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-10 19:08:11.228260: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-10 19:08:11.280020: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-10 19:08:13.398336: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/
# 2024-06-10 19:08:13.398507: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/
# 2024-06-10 19:08:13.398521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflow/experimental/utils.py:42: UserWarning: You're calling gpflow.experimental.check_shapes.decorator.check_shapes which is considered *experimental*. Expect: breaking changes, poor documentation, and bugs.
#   warn(
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflow/experimental/utils.py:42: UserWarning: You're calling gpflow.experimental.check_shapes.inheritance.inherit_check_shapes which is considered *experimental*. Expect: breaking changes, poor documentation, and bugs.
#   warn(
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# Using GPU #2
# Using GPU #2

# %% [markdown]
# ## 1. Preparing Dataset

# %% [markdown]
# ## 2. Loading Dataset

# %%
file_path = os.path.join(data_folder_path, 'CITEseq', 'pbmc5k_citeseq.h5mu')
mdata = mu.read(file_path)
mu.pp.intersect_obs(mdata)
rna = mdata.mod['rna']
rna = rna[:,rna.var.highly_variable]
prot = mdata.mod['prot']

#col_dict1 = {i:j for i,j in zip([list(set(rna.obs["celltype"]))[i] for i in range(0, len(set(rna.obs["celltype"])))],  rna.uns["celltype_colors"])}
#col_dict1[None] = '#CDC9C9'
col_dict1 = {'CD14 mono': '#8000ff',
                 'memory-like NK': '#5641fd',
                 'CD8+ naïve T': '#2c7ef7',
                 'pDC': '#00b5eb',
                 'CD16 mono': '#2adddd',
                 'intermediate mono': '#54f6cb',
                 'CD4+ naïve T': '#80ffb4',
                 'mature B': '#abf69b',
                 'CD4+ memory T': '#d4dd80',
                 'NK': '#ffb360',
                 'CD8+ memory T': '#ff7e41',
                 'pre-B': '#ff4121',
                 'Treg': '#ff0000',
                 None: '#CDC9C9'}
    
cell_type_list1=['CD4+ naïve T','CD4+ memory T','intermediate mono','CD8+ memory T','CD14 mono',
                   'NK','intermediate mono','mature B','pre-B','memory-like NK','intermediate mono', 
                   'CD16 mono','Treg','CD8+ naïve T','pDC']
cell_type_list_modified1=cell_type_list1
rank_genes_groups=rna.uns["rank_genes_groups"]["names"]

cell_type_list2=['CD4+ naïve T', 'CD4+ memory T', 'Treg','CD8+ naïve T','CD8+ memory T','NK','memory-like NK',
               'pre-B','mature B', 'CD14 mono','intermediate mono','CD16 mono','pDC']
rank_prots_groups=prot.uns["rank_genes_groups"]["names"]
cell_type_list_modified2=['CD4+ naïve T', 'CD4+ memory T', 'Treg','CD8+ naïve T','CD8+ memory T','NK','memory-like NK',
                 'pre-B','mature B', 'CD14 mono','intermediate mono','CD16 mono','pDC']

# %%
rna
# Out:
# View of AnnData object with n_obs × n_vars = 3891 × 1734
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'celltype'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
prot
# Out:
# AnnData object with n_obs × n_vars = 3891 × 32
#     obs: 'celltype'
#     var: 'gene_ids', 'feature_types', 'highly_variable'
#     uns: 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
#Sampling
num_rows = 800
num_cols = 800

file_path='./Results/num_rows'+str(num_rows)+'num_cols'+str(num_cols)+'.csv'
if os.path.exists(file_path):
    file = open(file_path,"rb")
    row_indices = pickle.load(file)
    col_indices = pickle.load(file)
else:
    np.random.seed(0)  # For reproducibility
    row_indices = np.random.choice(rna.X.shape[0], num_rows, replace=False)
    col_indices = np.random.choice(rna.X.shape[1], num_cols, replace=False)
    os.makedirs("./Results", exist_ok=True)
    filehandler = open(file_path,"wb")
    pickle.dump(row_indices,filehandler)
    pickle.dump(col_indices,filehandler)
    
matrix1 = rna.X[row_indices, :][:,col_indices]
matrix2 = prot.X[row_indices, :]

# %%
RNA_Normalized_2000 = (matrix1-np.mean(matrix1,0))/np.std(matrix1,0)

prot_Normalized_2000 = (matrix2-np.mean(matrix2,0))/np.std(matrix2,0)

# %%
[cells,genes] = RNA_Normalized_2000.shape

# %%
np.random.seed(11111986)
[I,J] = RNA_Normalized_2000.shape
[I,K] = prot_Normalized_2000.shape

# %%
[i,j] = np.nonzero(RNA_Normalized_2000)
X_tr1 = []
for cnt in range(len(i)):
    X_tr1.append([i[cnt],j[cnt]])
X_tr1 = np.asarray(X_tr1)
Y_tr1 = RNA_Normalized_2000.ravel()

# %%
[i,j] = np.nonzero(prot_Normalized_2000)
X_tr2 = []
for cnt in range(len(i)):
    X_tr2.append([i[cnt],j[cnt]])
X_tr2 = np.asarray(X_tr2)
Y_tr2 = prot_Normalized_2000.ravel()

# %% [markdown]
# ## 3. Defining the model

# %% [markdown]
# ## 4. Running

# %% [markdown]
# ### num_epochs = 100

# %%
dim1 = 2
dim2 = 2
dim3 = 2
num_epochs = 100
n_inducing_points1 = 512
n_inducing_points2 = 512
batch_size = 10000
with_PCA = 0
with_PPCA = 0
scale_emb1 = 0
scale_emb2 = 0
emb_reg = float(0.001)
lr = float(0.01)
kernel = ["RBF"]

# %%
title = 'cells='+str(num_rows)+'  genes='+str(num_cols)+'  dim1='+str(dim1)+'  dim2='+str(dim2)+'  dim3='+str(dim3)+'  InducingPoints1='+str(n_inducing_points1)+'  InducingPoints2='+str(n_inducing_points2)+'  BatchSize='+str(batch_size)+'  epochs='+str(num_epochs)+'  emb_reg='+str(emb_reg)+ ' with_PCA='+str(with_PCA)
save_path = './RunningPBMC5KCITEseqRNA-GPFlux '+title+'/' 
hyper_params = {
'I':I,
'J':J,
'K':None,    # the number of entities in each domain
'M1': n_inducing_points1,                  # the number of inducing pairs
'M2': n_inducing_points2,                  # the number of inducing pairs
'emb_sizes': [dim1,dim2,dim3],      # the embedding sizes
'batch_size':batch_size,      # the size of training batches
'obs_mean1': Y_tr1.mean(),  # the mean of target
'obs_mean2': Y_tr2.mean(),  # the mean of target
'emb_reg': emb_reg,          # l2 norm on the embeddings
'lr': lr,                # the learning rate 
'save_path': save_path,        # path to save the trained models.
}  

gp_md = GPD(**hyper_params)
if with_PCA == 0:
    gp_md.build(kernels=kernel)

#hist= gp_md.train((X_tr1+1).astype(int), Y_tr1, X_tr2=None, Y_tr2=None, n_iter=num_epochs)
hist= gp_md.train((X_tr1+1).astype(int), Y_tr1, X_tr2=(X_tr2+1).astype(int), Y_tr2=Y_tr2, n_iter=num_epochs)
#hist= gp_md.train((X_tr1).astype(int), Y_tr1, X_tr2=(X_tr2).astype(int), Y_tr2=Y_tr2, n_iter=num_epochs)
# Out:
# 2024-06-10 19:09:12.426497: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-10 19:09:13.167683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14778 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:86:00.0, compute capability: 7.5
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflow/experimental/utils.py:42: UserWarning: You're calling gpflow.experimental.check_shapes.checker.ShapeChecker.__init__ which is considered *experimental*. Expect: breaking changes, poor documentation, and bugs.
#   warn(
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflux/layers/gp_layer.py:175: UserWarning: Beware, no mean function was specified in the construction of the `GPLayer` so the default `gpflow.mean_functions.Identity` is being used. This mean function will only work if the input dimensionality matches the number of latent Gaussian processes in the layer.
#   warnings.warn(
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflux/layers/gp_layer.py:198: UserWarning: Could not verify the compatibility of the `kernel`, `inducing_variable` and `mean_function`. We advise using `gpflux.helpers.construct_*` to create compatible kernels and inducing variables. As `num_latent_gps=4` has been specified explicitly, this will be used to create the `q_mu` and `q_sqrt` parameters.
#   warnings.warn(
# WARNING:tensorflow:From /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/tensorflow_probability/python/distributions/distribution.py:342: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it into `scale_diag` directly instead.
# Epoch 1/100
# 2024-06-10 19:09:19.045810: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x55963a9cc1f0
# 64/64 [==============================] - ETA: 0s - loss: 35.4610 - gp_layer_prior_kl: 1.2824e-05
# Epoch 1: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 22s 266ms/step - loss: 35.4610 - gp_layer_prior_kl: 1.2824e-05
# Epoch 2/100
# 64/64 [==============================] - ETA: 0s - loss: 23.1203 - gp_layer_prior_kl: 1.2247e-04
# Epoch 2: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 23.1203 - gp_layer_prior_kl: 1.2247e-04
# Epoch 3/100
# 64/64 [==============================] - ETA: 0s - loss: 17.0799 - gp_layer_prior_kl: 1.6595e-04
# Epoch 3: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 17.0799 - gp_layer_prior_kl: 1.6595e-04
# Epoch 4/100
# 64/64 [==============================] - ETA: 0s - loss: 16.4117 - gp_layer_prior_kl: 1.8757e-04
# Epoch 4: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 16.4117 - gp_layer_prior_kl: 1.8757e-04
# Epoch 5/100
# 64/64 [==============================] - ETA: 0s - loss: 15.8001 - gp_layer_prior_kl: 2.0529e-04
# Epoch 5: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 15.8001 - gp_layer_prior_kl: 2.0529e-04
# Epoch 6/100
# 64/64 [==============================] - ETA: 0s - loss: 15.2262 - gp_layer_prior_kl: 2.2185e-04
# Epoch 6: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 15.2262 - gp_layer_prior_kl: 2.2185e-04
# Epoch 7/100
# 64/64 [==============================] - ETA: 0s - loss: 14.6809 - gp_layer_prior_kl: 2.3436e-04
# Epoch 7: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 14.6809 - gp_layer_prior_kl: 2.3436e-04
# Epoch 8/100
# 64/64 [==============================] - ETA: 0s - loss: 14.1665 - gp_layer_prior_kl: 2.4325e-04
# Epoch 8: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 14.1665 - gp_layer_prior_kl: 2.4325e-04
# Epoch 9/100
# 64/64 [==============================] - ETA: 0s - loss: 13.6803 - gp_layer_prior_kl: 2.5249e-04
# Epoch 9: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 13.6803 - gp_layer_prior_kl: 2.5249e-04
# Epoch 10/100
# 64/64 [==============================] - ETA: 0s - loss: 13.2552 - gp_layer_prior_kl: 2.7656e-04
# Epoch 10: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 13.2552 - gp_layer_prior_kl: 2.7656e-04
# Epoch 11/100
# 64/64 [==============================] - ETA: 0s - loss: 12.7844 - gp_layer_prior_kl: 3.0552e-04
# Epoch 11: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 12.7844 - gp_layer_prior_kl: 3.0552e-04
# Epoch 12/100
# 64/64 [==============================] - ETA: 0s - loss: 12.3724 - gp_layer_prior_kl: 3.1531e-04
# Epoch 12: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 12.3724 - gp_layer_prior_kl: 3.1531e-04
# Epoch 13/100
# 64/64 [==============================] - ETA: 0s - loss: 11.9828 - gp_layer_prior_kl: 3.2623e-04
# Epoch 13: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 11.9828 - gp_layer_prior_kl: 3.2623e-04
# Epoch 14/100
# 64/64 [==============================] - ETA: 0s - loss: 11.6131 - gp_layer_prior_kl: 3.4081e-04
# Epoch 14: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 11.6131 - gp_layer_prior_kl: 3.4081e-04
# Epoch 15/100
# 64/64 [==============================] - ETA: 0s - loss: 11.2612 - gp_layer_prior_kl: 3.6221e-04
# Epoch 15: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 11.2612 - gp_layer_prior_kl: 3.6221e-04
# Epoch 16/100
# 64/64 [==============================] - ETA: 0s - loss: 10.9107 - gp_layer_prior_kl: 3.9095e-04
# Epoch 16: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 10.9107 - gp_layer_prior_kl: 3.9095e-04
# Epoch 17/100
# 64/64 [==============================] - ETA: 0s - loss: 10.5526 - gp_layer_prior_kl: 4.2811e-04
# Epoch 17: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 10.5526 - gp_layer_prior_kl: 4.2811e-04
# Epoch 18/100
# 64/64 [==============================] - ETA: 0s - loss: 10.1620 - gp_layer_prior_kl: 4.8289e-04
# Epoch 18: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 10.1620 - gp_layer_prior_kl: 4.8289e-04
# Epoch 19/100
# 64/64 [==============================] - ETA: 0s - loss: 9.6994 - gp_layer_prior_kl: 5.7556e-04
# Epoch 19: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 9.6994 - gp_layer_prior_kl: 5.7556e-04
# Epoch 20/100
# 64/64 [==============================] - ETA: 0s - loss: 9.2430 - gp_layer_prior_kl: 6.8949e-04
# Epoch 20: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 9.2430 - gp_layer_prior_kl: 6.8949e-04
# Epoch 21/100
# 64/64 [==============================] - ETA: 0s - loss: 8.9479 - gp_layer_prior_kl: 7.7481e-04
# Epoch 21: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 8.9479 - gp_layer_prior_kl: 7.7481e-04
# Epoch 22/100
# 64/64 [==============================] - ETA: 0s - loss: 8.7404 - gp_layer_prior_kl: 8.2116e-04
# Epoch 22: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 8.7404 - gp_layer_prior_kl: 8.2116e-04
# Epoch 23/100
# 64/64 [==============================] - ETA: 0s - loss: 8.5601 - gp_layer_prior_kl: 8.4890e-04
# Epoch 23: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 8.5601 - gp_layer_prior_kl: 8.4890e-04
# Epoch 24/100
# 64/64 [==============================] - ETA: 0s - loss: 8.3981 - gp_layer_prior_kl: 8.6814e-04
# Epoch 24: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 8.3981 - gp_layer_prior_kl: 8.6814e-04
# Epoch 25/100
# 64/64 [==============================] - ETA: 0s - loss: 8.2430 - gp_layer_prior_kl: 8.8257e-04
# Epoch 25: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 8.2430 - gp_layer_prior_kl: 8.8257e-04
# Epoch 26/100
# 64/64 [==============================] - ETA: 0s - loss: 8.0997 - gp_layer_prior_kl: 8.9512e-04
# Epoch 26: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 8.0997 - gp_layer_prior_kl: 8.9512e-04
# Epoch 27/100
# 64/64 [==============================] - ETA: 0s - loss: 7.9595 - gp_layer_prior_kl: 9.0491e-04
# Epoch 27: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 7.9595 - gp_layer_prior_kl: 9.0491e-04
# Epoch 28/100
# 64/64 [==============================] - ETA: 0s - loss: 7.8282 - gp_layer_prior_kl: 9.1165e-04
# Epoch 28: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 7.8282 - gp_layer_prior_kl: 9.1165e-04
# Epoch 29/100
# 64/64 [==============================] - ETA: 0s - loss: 7.7074 - gp_layer_prior_kl: 9.2013e-04
# Epoch 29: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 7.7074 - gp_layer_prior_kl: 9.2013e-04
# Epoch 30/100
# 64/64 [==============================] - ETA: 0s - loss: 7.5867 - gp_layer_prior_kl: 9.2879e-04
# Epoch 30: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 7.5867 - gp_layer_prior_kl: 9.2879e-04
# Epoch 31/100
# 64/64 [==============================] - ETA: 0s - loss: 7.4750 - gp_layer_prior_kl: 9.3427e-04
# Epoch 31: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 7.4750 - gp_layer_prior_kl: 9.3427e-04
# Epoch 32/100
# 64/64 [==============================] - ETA: 0s - loss: 7.3696 - gp_layer_prior_kl: 9.4050e-04
# Epoch 32: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 7.3696 - gp_layer_prior_kl: 9.4050e-04
# Epoch 33/100
# 64/64 [==============================] - ETA: 0s - loss: 7.2696 - gp_layer_prior_kl: 9.4716e-04
# Epoch 33: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 7.2696 - gp_layer_prior_kl: 9.4716e-04
# Epoch 34/100
# 64/64 [==============================] - ETA: 0s - loss: 7.1729 - gp_layer_prior_kl: 9.5437e-04
# Epoch 34: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 7.1729 - gp_layer_prior_kl: 9.5437e-04
# Epoch 35/100
# 64/64 [==============================] - ETA: 0s - loss: 7.0821 - gp_layer_prior_kl: 9.5904e-04
# Epoch 35: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 7.0821 - gp_layer_prior_kl: 9.5904e-04
# Epoch 36/100
# 64/64 [==============================] - ETA: 0s - loss: 6.9963 - gp_layer_prior_kl: 9.6624e-04
# Epoch 36: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.9963 - gp_layer_prior_kl: 9.6624e-04
# Epoch 37/100
# 64/64 [==============================] - ETA: 0s - loss: 6.9148 - gp_layer_prior_kl: 9.7352e-04
# Epoch 37: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.9148 - gp_layer_prior_kl: 9.7352e-04
# Epoch 38/100
# 64/64 [==============================] - ETA: 0s - loss: 6.8382 - gp_layer_prior_kl: 9.8232e-04
# Epoch 38: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.8382 - gp_layer_prior_kl: 9.8232e-04
# Epoch 39/100
# 64/64 [==============================] - ETA: 0s - loss: 6.7627 - gp_layer_prior_kl: 9.8937e-04
# Epoch 39: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.7627 - gp_layer_prior_kl: 9.8937e-04
# Epoch 40/100
# 64/64 [==============================] - ETA: 0s - loss: 6.6933 - gp_layer_prior_kl: 9.9601e-04
# Epoch 40: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.6933 - gp_layer_prior_kl: 9.9601e-04
# Epoch 41/100
# 64/64 [==============================] - ETA: 0s - loss: 6.6257 - gp_layer_prior_kl: 0.0010
# Epoch 41: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.6257 - gp_layer_prior_kl: 0.0010
# Epoch 42/100
# 64/64 [==============================] - ETA: 0s - loss: 6.5631 - gp_layer_prior_kl: 0.0010
# Epoch 42: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.5631 - gp_layer_prior_kl: 0.0010
# Epoch 43/100
# 64/64 [==============================] - ETA: 0s - loss: 6.5039 - gp_layer_prior_kl: 0.0010
# Epoch 43: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 6.5039 - gp_layer_prior_kl: 0.0010
# Epoch 44/100
# 64/64 [==============================] - ETA: 0s - loss: 6.4464 - gp_layer_prior_kl: 0.0010
# Epoch 44: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 6.4464 - gp_layer_prior_kl: 0.0010
# Epoch 45/100
# 64/64 [==============================] - ETA: 0s - loss: 6.3922 - gp_layer_prior_kl: 0.0010
# Epoch 45: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.3922 - gp_layer_prior_kl: 0.0010
# Epoch 46/100
# 64/64 [==============================] - ETA: 0s - loss: 6.3399 - gp_layer_prior_kl: 0.0010
# Epoch 46: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.3399 - gp_layer_prior_kl: 0.0010
# Epoch 47/100
# 64/64 [==============================] - ETA: 0s - loss: 6.2915 - gp_layer_prior_kl: 0.0010
# Epoch 47: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.2915 - gp_layer_prior_kl: 0.0010
# Epoch 48/100
# 64/64 [==============================] - ETA: 0s - loss: 6.2450 - gp_layer_prior_kl: 0.0011
# Epoch 48: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.2450 - gp_layer_prior_kl: 0.0011
# Epoch 49/100
# 64/64 [==============================] - ETA: 0s - loss: 6.2011 - gp_layer_prior_kl: 0.0011
# Epoch 49: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.2011 - gp_layer_prior_kl: 0.0011
# Epoch 50/100
# 64/64 [==============================] - ETA: 0s - loss: 6.1587 - gp_layer_prior_kl: 0.0011
# Epoch 50: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.1587 - gp_layer_prior_kl: 0.0011
# Epoch 51/100
# 64/64 [==============================] - ETA: 0s - loss: 6.1187 - gp_layer_prior_kl: 0.0011
# Epoch 51: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.1187 - gp_layer_prior_kl: 0.0011
# Epoch 52/100
# 64/64 [==============================] - ETA: 0s - loss: 6.0818 - gp_layer_prior_kl: 0.0011
# Epoch 52: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.0818 - gp_layer_prior_kl: 0.0011
# Epoch 53/100
# 64/64 [==============================] - ETA: 0s - loss: 6.0457 - gp_layer_prior_kl: 0.0011
# Epoch 53: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.0457 - gp_layer_prior_kl: 0.0011
# Epoch 54/100
# 64/64 [==============================] - ETA: 0s - loss: 6.0111 - gp_layer_prior_kl: 0.0011
# Epoch 54: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.0111 - gp_layer_prior_kl: 0.0011
# Epoch 55/100
# 64/64 [==============================] - ETA: 0s - loss: 5.9794 - gp_layer_prior_kl: 0.0011
# Epoch 55: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.9794 - gp_layer_prior_kl: 0.0011
# Epoch 56/100
# 64/64 [==============================] - ETA: 0s - loss: 5.9486 - gp_layer_prior_kl: 0.0011
# Epoch 56: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.9486 - gp_layer_prior_kl: 0.0011
# Epoch 57/100
# 64/64 [==============================] - ETA: 0s - loss: 5.9194 - gp_layer_prior_kl: 0.0011
# Epoch 57: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.9194 - gp_layer_prior_kl: 0.0011
# Epoch 58/100
# 64/64 [==============================] - ETA: 0s - loss: 5.8914 - gp_layer_prior_kl: 0.0011
# Epoch 58: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.8914 - gp_layer_prior_kl: 0.0011
# Epoch 59/100
# 64/64 [==============================] - ETA: 0s - loss: 5.8659 - gp_layer_prior_kl: 0.0012
# Epoch 59: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.8659 - gp_layer_prior_kl: 0.0012
# Epoch 60/100
# 64/64 [==============================] - ETA: 0s - loss: 5.8403 - gp_layer_prior_kl: 0.0012
# Epoch 60: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.8403 - gp_layer_prior_kl: 0.0012
# Epoch 61/100
# 64/64 [==============================] - ETA: 0s - loss: 5.8165 - gp_layer_prior_kl: 0.0012
# Epoch 61: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.8165 - gp_layer_prior_kl: 0.0012
# Epoch 62/100
# 64/64 [==============================] - ETA: 0s - loss: 5.7947 - gp_layer_prior_kl: 0.0012
# Epoch 62: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.7947 - gp_layer_prior_kl: 0.0012
# Epoch 63/100
# 64/64 [==============================] - ETA: 0s - loss: 5.7737 - gp_layer_prior_kl: 0.0012
# Epoch 63: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.7737 - gp_layer_prior_kl: 0.0012
# Epoch 64/100
# 64/64 [==============================] - ETA: 0s - loss: 5.7540 - gp_layer_prior_kl: 0.0012
# Epoch 64: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 269ms/step - loss: 5.7540 - gp_layer_prior_kl: 0.0012
# Epoch 65/100
# 64/64 [==============================] - ETA: 0s - loss: 5.7349 - gp_layer_prior_kl: 0.0012
# Epoch 65: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.7349 - gp_layer_prior_kl: 0.0012
# Epoch 66/100
# 64/64 [==============================] - ETA: 0s - loss: 5.7171 - gp_layer_prior_kl: 0.0012
# Epoch 66: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.7171 - gp_layer_prior_kl: 0.0012
# Epoch 67/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6998 - gp_layer_prior_kl: 0.0012
# Epoch 67: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.6998 - gp_layer_prior_kl: 0.0012
# Epoch 68/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6841 - gp_layer_prior_kl: 0.0012
# Epoch 68: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.6841 - gp_layer_prior_kl: 0.0012
# Epoch 69/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6688 - gp_layer_prior_kl: 0.0012
# Epoch 69: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.6688 - gp_layer_prior_kl: 0.0012
# Epoch 70/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6550 - gp_layer_prior_kl: 0.0013
# Epoch 70: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.6550 - gp_layer_prior_kl: 0.0013
# Epoch 71/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6412 - gp_layer_prior_kl: 0.0013
# Epoch 71: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.6412 - gp_layer_prior_kl: 0.0013
# Epoch 72/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6294 - gp_layer_prior_kl: 0.0013
# Epoch 72: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.6294 - gp_layer_prior_kl: 0.0013
# Epoch 73/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6173 - gp_layer_prior_kl: 0.0013
# Epoch 73: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.6173 - gp_layer_prior_kl: 0.0013
# Epoch 74/100
# 64/64 [==============================] - ETA: 0s - loss: 5.6057 - gp_layer_prior_kl: 0.0013
# Epoch 74: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.6057 - gp_layer_prior_kl: 0.0013
# Epoch 75/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5954 - gp_layer_prior_kl: 0.0013
# Epoch 75: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5954 - gp_layer_prior_kl: 0.0013
# Epoch 76/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5857 - gp_layer_prior_kl: 0.0013
# Epoch 76: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5857 - gp_layer_prior_kl: 0.0013
# Epoch 77/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5770 - gp_layer_prior_kl: 0.0013
# Epoch 77: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.5770 - gp_layer_prior_kl: 0.0013
# Epoch 78/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5680 - gp_layer_prior_kl: 0.0013
# Epoch 78: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5680 - gp_layer_prior_kl: 0.0013
# Epoch 79/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5598 - gp_layer_prior_kl: 0.0013
# Epoch 79: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.5598 - gp_layer_prior_kl: 0.0013
# Epoch 80/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5518 - gp_layer_prior_kl: 0.0013
# Epoch 80: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5518 - gp_layer_prior_kl: 0.0013
# Epoch 81/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5449 - gp_layer_prior_kl: 0.0013
# Epoch 81: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5449 - gp_layer_prior_kl: 0.0013
# Epoch 82/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5382 - gp_layer_prior_kl: 0.0014
# Epoch 82: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5382 - gp_layer_prior_kl: 0.0014
# Epoch 83/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5323 - gp_layer_prior_kl: 0.0014
# Epoch 83: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5323 - gp_layer_prior_kl: 0.0014
# Epoch 84/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5268 - gp_layer_prior_kl: 0.0014
# Epoch 84: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5268 - gp_layer_prior_kl: 0.0014
# Epoch 85/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5210 - gp_layer_prior_kl: 0.0014
# Epoch 85: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5210 - gp_layer_prior_kl: 0.0014
# Epoch 86/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5153 - gp_layer_prior_kl: 0.0014
# Epoch 86: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5153 - gp_layer_prior_kl: 0.0014
# Epoch 87/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5107 - gp_layer_prior_kl: 0.0014
# Epoch 87: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.5107 - gp_layer_prior_kl: 0.0014
# Epoch 88/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5063 - gp_layer_prior_kl: 0.0014
# Epoch 88: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.5063 - gp_layer_prior_kl: 0.0014
# Epoch 89/100
# 64/64 [==============================] - ETA: 0s - loss: 5.5027 - gp_layer_prior_kl: 0.0014
# Epoch 89: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.5027 - gp_layer_prior_kl: 0.0014
# Epoch 90/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4991 - gp_layer_prior_kl: 0.0014
# Epoch 90: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.4991 - gp_layer_prior_kl: 0.0014
# Epoch 91/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4955 - gp_layer_prior_kl: 0.0014
# Epoch 91: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.4955 - gp_layer_prior_kl: 0.0014
# Epoch 92/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4921 - gp_layer_prior_kl: 0.0014
# Epoch 92: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.4921 - gp_layer_prior_kl: 0.0014
# Epoch 93/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4890 - gp_layer_prior_kl: 0.0014
# Epoch 93: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4890 - gp_layer_prior_kl: 0.0014
# Epoch 94/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4864 - gp_layer_prior_kl: 0.0014
# Epoch 94: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4864 - gp_layer_prior_kl: 0.0014
# Epoch 95/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4839 - gp_layer_prior_kl: 0.0014
# Epoch 95: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4839 - gp_layer_prior_kl: 0.0014
# Epoch 96/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4814 - gp_layer_prior_kl: 0.0014
# Epoch 96: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4814 - gp_layer_prior_kl: 0.0014
# Epoch 97/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4792 - gp_layer_prior_kl: 0.0014
# Epoch 97: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 271ms/step - loss: 5.4792 - gp_layer_prior_kl: 0.0014
# Epoch 98/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4773 - gp_layer_prior_kl: 0.0014
# Epoch 98: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4773 - gp_layer_prior_kl: 0.0014
# Epoch 99/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4760 - gp_layer_prior_kl: 0.0015
# Epoch 99: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4760 - gp_layer_prior_kl: 0.0015
# Epoch 100/100
# 64/64 [==============================] - ETA: 0s - loss: 5.4740 - gp_layer_prior_kl: 0.0015
# Epoch 100: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=100  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4740 - gp_layer_prior_kl: 0.0015

# %%
dim1 = 2
dim2 = 2
dim3 = 2
num_epochs = 100
n_inducing_points1 = 512
n_inducing_points2 = 512
batch_size = 10000
with_PCA = 0
with_PPCA = 0
scale_emb1 = 0
scale_emb2 = 0
emb_reg = 0.001
lr = float(0.01)
kernel = ["RBF"]
if (with_PCA==0 or with_PPCA==0):
    title = 'cells='+str(num_rows)+'  genes='+str(num_cols)+'  dim1='+str(dim1)+'  dim2='+str(dim2)+'  dim3='+str(dim3)+'  InducingPoints1='+str(n_inducing_points1)+'  InducingPoints2='+str(n_inducing_points2)+'  BatchSize='+str(batch_size)+'  epochs='+str(num_epochs)+'  emb_reg='+str(emb_reg)+ ' with_PCA='+str(with_PCA)
    save_path = './RunningPBMC5KCITEseqRNA-GPFlux '+title+'/' 
    #save_path='./PBMC5KCITEseq2View-GPFlux  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=500  emb_reg=0.001 with_PCA=0'
    hyper_params = {
    'I':I,
    'J':J,
    'K':None,    # the number of entities in each domain
    'M1': n_inducing_points1,                  # the number of inducing pairs
    'M2': n_inducing_points2,                  # the number of inducing pairs
    'emb_sizes': [dim1,dim2,dim3],      # the embedding sizes
    'batch_size':batch_size,      # the size of training batches
    'obs_mean1': Y_tr1.mean(),  # the mean of target
    'obs_mean2': None,  # the mean of target
    'emb_reg': emb_reg,          # l2 norm on the embeddings
    'lr': lr,                # the learning rate 
    'save_path': save_path,        # path to save the trained models.
    }  
    
    gp_md = GPD(**hyper_params)
    gp_md.build(kernels=kernel)
    gp_md.load_model((X_tr1+1), None)
    
    emb1 = gp_md.emb1
    embs1 = emb1((X_tr1+1)[0:-1:J,0])
    
    emb2 = gp_md.emb2
    embs2 = emb2((X_tr1+1)[0:J,1])
    
    RNA_struct_MOGP = ad.AnnData(embs1.numpy())
    RNA_struct_MOGP.obsm['X_tsne']= embs1.numpy()
    
    Genes_struct_MOGP = ad.AnnData(embs2.numpy())
    Genes_struct_MOGP.obsm['X_tsne']= embs2.numpy()
    
    RNA_struct_sampled = ad.AnnData(rna.X[row_indices,:][:,col_indices])
    RNA_struct_sampled.var_names=rna.var_names[col_indices]
    RNA_struct_sampled.obs_names=rna.obs_names[row_indices]
    RNA_struct_sampled.obs["celltype"]=rna.obs["celltype"][row_indices]
    RNA_struct_sampled.uns["rank_genes_groups"]=rna.uns["rank_genes_groups"]
    
    Relating_clusters_of_emb1_to_clusters_of_emb2_CITEseq(RNA_struct_sampled, None, RNA_struct_MOGP, Genes_struct_MOGP, Prot_struct_MOGP=None, col_dict1=col_dict1, cell_type_list_modified1=cell_type_list_modified1, cell_type_list_modified2=cell_type_list_modified2, n_cell_types=len(list(set(rna.obs["celltype"]))),n_marker_genes=100, use_umap=False)

# %% [markdown]
# ### num_epochs = 200

# %%
num_epochs = 200
title = 'cells='+str(num_rows)+'  genes='+str(num_cols)+'  dim1='+str(dim1)+'  dim2='+str(dim2)+'  dim3='+str(dim3)+'  InducingPoints1='+str(n_inducing_points1)+'  InducingPoints2='+str(n_inducing_points2)+'  BatchSize='+str(batch_size)+'  epochs='+str(num_epochs)+'  emb_reg='+str(emb_reg)+ ' with_PCA='+str(with_PCA)
save_path = './RunningPBMC5KCITEseqRNA-GPFlux '+title+'/' 
hyper_params = {
'I':I,
'J':J,
'K':None,    # the number of entities in each domain
'M1': n_inducing_points1,                  # the number of inducing pairs
'M2': n_inducing_points2,                  # the number of inducing pairs
'emb_sizes': [dim1,dim2,dim3],      # the embedding sizes
'batch_size':batch_size,      # the size of training batches
'obs_mean1': Y_tr1.mean(),  # the mean of target
'obs_mean2': Y_tr2.mean(),  # the mean of target
'emb_reg': emb_reg,          # l2 norm on the embeddings
'lr': lr,                # the learning rate 
'save_path': save_path,        # path to save the trained models.
}  

gp_md = GPD(**hyper_params)
if with_PCA == 0:
    gp_md.build(kernels=kernel)

#hist= gp_md.train((X_tr1+1).astype(int), Y_tr1, X_tr2=None, Y_tr2=None, n_iter=num_epochs)
hist= gp_md.train((X_tr1+1).astype(int), Y_tr1, X_tr2=(X_tr2+1).astype(int), Y_tr2=Y_tr2, n_iter=num_epochs)
#hist= gp_md.train((X_tr1).astype(int), Y_tr1, X_tr2=(X_tr2).astype(int), Y_tr2=Y_tr2, n_iter=num_epochs)
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflux/layers/gp_layer.py:175: UserWarning: Beware, no mean function was specified in the construction of the `GPLayer` so the default `gpflow.mean_functions.Identity` is being used. This mean function will only work if the input dimensionality matches the number of latent Gaussian processes in the layer.
#   warnings.warn(
# /home/zmoslehi/miniconda3/envs/MOGP-TF-Florian/lib/python3.9/site-packages/gpflux/layers/gp_layer.py:198: UserWarning: Could not verify the compatibility of the `kernel`, `inducing_variable` and `mean_function`. We advise using `gpflux.helpers.construct_*` to create compatible kernels and inducing variables. As `num_latent_gps=4` has been specified explicitly, this will be used to create the `q_mu` and `q_sqrt` parameters.
#   warnings.warn(
# Epoch 1/200
# 64/64 [==============================] - ETA: 0s - loss: 35.3124 - gp_layer_2_prior_kl: 1.7068e-05
# Epoch 1: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 19s 263ms/step - loss: 35.3124 - gp_layer_2_prior_kl: 1.7068e-05
# Epoch 2/200
# 64/64 [==============================] - ETA: 0s - loss: 23.0397 - gp_layer_2_prior_kl: 1.0035e-04
# Epoch 2: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 23.0397 - gp_layer_2_prior_kl: 1.0035e-04
# Epoch 3/200
# 64/64 [==============================] - ETA: 0s - loss: 17.0844 - gp_layer_2_prior_kl: 1.3989e-04
# Epoch 3: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 17.0844 - gp_layer_2_prior_kl: 1.3989e-04
# Epoch 4/200
# 64/64 [==============================] - ETA: 0s - loss: 16.4073 - gp_layer_2_prior_kl: 1.6718e-04
# Epoch 4: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 16.4073 - gp_layer_2_prior_kl: 1.6718e-04
# Epoch 5/200
# 64/64 [==============================] - ETA: 0s - loss: 15.7888 - gp_layer_2_prior_kl: 1.9150e-04
# Epoch 5: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 262ms/step - loss: 15.7888 - gp_layer_2_prior_kl: 1.9150e-04
# Epoch 6/200
# 64/64 [==============================] - ETA: 0s - loss: 15.2096 - gp_layer_2_prior_kl: 2.0981e-04
# Epoch 6: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 15.2096 - gp_layer_2_prior_kl: 2.0981e-04
# Epoch 7/200
# 64/64 [==============================] - ETA: 0s - loss: 14.6681 - gp_layer_2_prior_kl: 2.2142e-04
# Epoch 7: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 14.6681 - gp_layer_2_prior_kl: 2.2142e-04
# Epoch 8/200
# 64/64 [==============================] - ETA: 0s - loss: 14.1539 - gp_layer_2_prior_kl: 2.3002e-04
# Epoch 8: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 14.1539 - gp_layer_2_prior_kl: 2.3002e-04
# Epoch 9/200
# 64/64 [==============================] - ETA: 0s - loss: 13.6652 - gp_layer_2_prior_kl: 2.3829e-04
# Epoch 9: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 13.6652 - gp_layer_2_prior_kl: 2.3829e-04
# Epoch 10/200
# 64/64 [==============================] - ETA: 0s - loss: 13.2067 - gp_layer_2_prior_kl: 2.4593e-04
# Epoch 10: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 13.2067 - gp_layer_2_prior_kl: 2.4593e-04
# Epoch 11/200
# 64/64 [==============================] - ETA: 0s - loss: 12.7704 - gp_layer_2_prior_kl: 2.5592e-04
# Epoch 11: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 12.7704 - gp_layer_2_prior_kl: 2.5592e-04
# Epoch 12/200
# 64/64 [==============================] - ETA: 0s - loss: 12.3592 - gp_layer_2_prior_kl: 2.6827e-04
# Epoch 12: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 12.3592 - gp_layer_2_prior_kl: 2.6827e-04
# Epoch 13/200
# 64/64 [==============================] - ETA: 0s - loss: 11.9718 - gp_layer_2_prior_kl: 2.8240e-04
# Epoch 13: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 11.9718 - gp_layer_2_prior_kl: 2.8240e-04
# Epoch 14/200
# 64/64 [==============================] - ETA: 0s - loss: 11.6041 - gp_layer_2_prior_kl: 3.0100e-04
# Epoch 14: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 11.6041 - gp_layer_2_prior_kl: 3.0100e-04
# Epoch 15/200
# 64/64 [==============================] - ETA: 0s - loss: 11.2475 - gp_layer_2_prior_kl: 3.2842e-04
# Epoch 15: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 11.2475 - gp_layer_2_prior_kl: 3.2842e-04
# Epoch 16/200
# 64/64 [==============================] - ETA: 0s - loss: 10.8894 - gp_layer_2_prior_kl: 3.6512e-04
# Epoch 16: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 10.8894 - gp_layer_2_prior_kl: 3.6512e-04
# Epoch 17/200
# 64/64 [==============================] - ETA: 0s - loss: 10.4995 - gp_layer_2_prior_kl: 4.1917e-04
# Epoch 17: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 10.4995 - gp_layer_2_prior_kl: 4.1917e-04
# Epoch 18/200
# 64/64 [==============================] - ETA: 0s - loss: 10.0164 - gp_layer_2_prior_kl: 5.0223e-04
# Epoch 18: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 10.0164 - gp_layer_2_prior_kl: 5.0223e-04
# Epoch 19/200
# 64/64 [==============================] - ETA: 0s - loss: 9.4926 - gp_layer_2_prior_kl: 6.1736e-04
# Epoch 19: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 9.4926 - gp_layer_2_prior_kl: 6.1736e-04
# Epoch 20/200
# 64/64 [==============================] - ETA: 0s - loss: 9.1451 - gp_layer_2_prior_kl: 7.2185e-04
# Epoch 20: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 9.1451 - gp_layer_2_prior_kl: 7.2185e-04
# Epoch 21/200
# 64/64 [==============================] - ETA: 0s - loss: 8.9292 - gp_layer_2_prior_kl: 7.7448e-04
# Epoch 21: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 8.9292 - gp_layer_2_prior_kl: 7.7448e-04
# Epoch 22/200
# 64/64 [==============================] - ETA: 0s - loss: 8.7400 - gp_layer_2_prior_kl: 8.0635e-04
# Epoch 22: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 270ms/step - loss: 8.7400 - gp_layer_2_prior_kl: 8.0635e-04
# Epoch 23/200
# 64/64 [==============================] - ETA: 0s - loss: 8.5665 - gp_layer_2_prior_kl: 8.2733e-04
# Epoch 23: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 8.5665 - gp_layer_2_prior_kl: 8.2733e-04
# Epoch 24/200
# 64/64 [==============================] - ETA: 0s - loss: 8.4061 - gp_layer_2_prior_kl: 8.4662e-04
# Epoch 24: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 8.4061 - gp_layer_2_prior_kl: 8.4662e-04
# Epoch 25/200
# 64/64 [==============================] - ETA: 0s - loss: 8.2507 - gp_layer_2_prior_kl: 8.6423e-04
# Epoch 25: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 8.2507 - gp_layer_2_prior_kl: 8.6423e-04
# Epoch 26/200
# 64/64 [==============================] - ETA: 0s - loss: 8.1036 - gp_layer_2_prior_kl: 8.7762e-04
# Epoch 26: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 8.1036 - gp_layer_2_prior_kl: 8.7762e-04
# Epoch 27/200
# 64/64 [==============================] - ETA: 0s - loss: 7.9649 - gp_layer_2_prior_kl: 8.9064e-04
# Epoch 27: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 7.9649 - gp_layer_2_prior_kl: 8.9064e-04
# Epoch 28/200
# 64/64 [==============================] - ETA: 0s - loss: 7.8324 - gp_layer_2_prior_kl: 9.0157e-04
# Epoch 28: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 7.8324 - gp_layer_2_prior_kl: 9.0157e-04
# Epoch 29/200
# 64/64 [==============================] - ETA: 0s - loss: 7.7082 - gp_layer_2_prior_kl: 9.1138e-04
# Epoch 29: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 7.7082 - gp_layer_2_prior_kl: 9.1138e-04
# Epoch 30/200
# 64/64 [==============================] - ETA: 0s - loss: 7.5915 - gp_layer_2_prior_kl: 9.2175e-04
# Epoch 30: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 7.5915 - gp_layer_2_prior_kl: 9.2175e-04
# Epoch 31/200
# 64/64 [==============================] - ETA: 0s - loss: 7.4807 - gp_layer_2_prior_kl: 9.3749e-04
# Epoch 31: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 7.4807 - gp_layer_2_prior_kl: 9.3749e-04
# Epoch 32/200
# 64/64 [==============================] - ETA: 0s - loss: 7.3710 - gp_layer_2_prior_kl: 9.4790e-04
# Epoch 32: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 7.3710 - gp_layer_2_prior_kl: 9.4790e-04
# Epoch 33/200
# 64/64 [==============================] - ETA: 0s - loss: 7.2707 - gp_layer_2_prior_kl: 9.5531e-04
# Epoch 33: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 7.2707 - gp_layer_2_prior_kl: 9.5531e-04
# Epoch 34/200
# 64/64 [==============================] - ETA: 0s - loss: 7.1739 - gp_layer_2_prior_kl: 9.6434e-04
# Epoch 34: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 7.1739 - gp_layer_2_prior_kl: 9.6434e-04
# Epoch 35/200
# 64/64 [==============================] - ETA: 0s - loss: 7.0822 - gp_layer_2_prior_kl: 9.7070e-04
# Epoch 35: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 7.0822 - gp_layer_2_prior_kl: 9.7070e-04
# Epoch 36/200
# 64/64 [==============================] - ETA: 0s - loss: 6.9976 - gp_layer_2_prior_kl: 9.7809e-04
# Epoch 36: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.9976 - gp_layer_2_prior_kl: 9.7809e-04
# Epoch 37/200
# 64/64 [==============================] - ETA: 0s - loss: 6.9151 - gp_layer_2_prior_kl: 9.8777e-04
# Epoch 37: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.9151 - gp_layer_2_prior_kl: 9.8777e-04
# Epoch 38/200
# 64/64 [==============================] - ETA: 0s - loss: 6.8368 - gp_layer_2_prior_kl: 9.9511e-04
# Epoch 38: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.8368 - gp_layer_2_prior_kl: 9.9511e-04
# Epoch 39/200
# 64/64 [==============================] - ETA: 0s - loss: 6.7648 - gp_layer_2_prior_kl: 0.0010
# Epoch 39: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 270ms/step - loss: 6.7648 - gp_layer_2_prior_kl: 0.0010
# Epoch 40/200
# 64/64 [==============================] - ETA: 0s - loss: 6.6936 - gp_layer_2_prior_kl: 0.0010
# Epoch 40: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.6936 - gp_layer_2_prior_kl: 0.0010
# Epoch 41/200
# 64/64 [==============================] - ETA: 0s - loss: 6.6255 - gp_layer_2_prior_kl: 0.0010
# Epoch 41: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.6255 - gp_layer_2_prior_kl: 0.0010
# Epoch 42/200
# 64/64 [==============================] - ETA: 0s - loss: 6.5630 - gp_layer_2_prior_kl: 0.0010
# Epoch 42: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 6.5630 - gp_layer_2_prior_kl: 0.0010
# Epoch 43/200
# 64/64 [==============================] - ETA: 0s - loss: 6.5022 - gp_layer_2_prior_kl: 0.0010
# Epoch 43: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 6.5022 - gp_layer_2_prior_kl: 0.0010
# Epoch 44/200
# 64/64 [==============================] - ETA: 0s - loss: 6.4455 - gp_layer_2_prior_kl: 0.0010
# Epoch 44: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 6.4455 - gp_layer_2_prior_kl: 0.0010
# Epoch 45/200
# 64/64 [==============================] - ETA: 0s - loss: 6.3926 - gp_layer_2_prior_kl: 0.0010
# Epoch 45: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 6.3926 - gp_layer_2_prior_kl: 0.0010
# Epoch 46/200
# 64/64 [==============================] - ETA: 0s - loss: 6.3405 - gp_layer_2_prior_kl: 0.0011
# Epoch 46: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.3405 - gp_layer_2_prior_kl: 0.0011
# Epoch 47/200
# 64/64 [==============================] - ETA: 0s - loss: 6.2913 - gp_layer_2_prior_kl: 0.0011
# Epoch 47: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.2913 - gp_layer_2_prior_kl: 0.0011
# Epoch 48/200
# 64/64 [==============================] - ETA: 0s - loss: 6.2442 - gp_layer_2_prior_kl: 0.0011
# Epoch 48: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.2442 - gp_layer_2_prior_kl: 0.0011
# Epoch 49/200
# 64/64 [==============================] - ETA: 0s - loss: 6.2012 - gp_layer_2_prior_kl: 0.0011
# Epoch 49: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 6.2012 - gp_layer_2_prior_kl: 0.0011
# Epoch 50/200
# 64/64 [==============================] - ETA: 0s - loss: 6.1588 - gp_layer_2_prior_kl: 0.0011
# Epoch 50: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.1588 - gp_layer_2_prior_kl: 0.0011
# Epoch 51/200
# 64/64 [==============================] - ETA: 0s - loss: 6.1185 - gp_layer_2_prior_kl: 0.0011
# Epoch 51: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.1185 - gp_layer_2_prior_kl: 0.0011
# Epoch 52/200
# 64/64 [==============================] - ETA: 0s - loss: 6.0821 - gp_layer_2_prior_kl: 0.0011
# Epoch 52: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.0821 - gp_layer_2_prior_kl: 0.0011
# Epoch 53/200
# 64/64 [==============================] - ETA: 0s - loss: 6.0459 - gp_layer_2_prior_kl: 0.0011
# Epoch 53: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 6.0459 - gp_layer_2_prior_kl: 0.0011
# Epoch 54/200
# 64/64 [==============================] - ETA: 0s - loss: 6.0115 - gp_layer_2_prior_kl: 0.0011
# Epoch 54: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 6.0115 - gp_layer_2_prior_kl: 0.0011
# Epoch 55/200
# 64/64 [==============================] - ETA: 0s - loss: 5.9793 - gp_layer_2_prior_kl: 0.0011
# Epoch 55: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.9793 - gp_layer_2_prior_kl: 0.0011
# Epoch 56/200
# 64/64 [==============================] - ETA: 0s - loss: 5.9493 - gp_layer_2_prior_kl: 0.0011
# Epoch 56: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.9493 - gp_layer_2_prior_kl: 0.0011
# Epoch 57/200
# 64/64 [==============================] - ETA: 0s - loss: 5.9211 - gp_layer_2_prior_kl: 0.0011
# Epoch 57: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.9211 - gp_layer_2_prior_kl: 0.0011
# Epoch 58/200
# 64/64 [==============================] - ETA: 0s - loss: 5.8922 - gp_layer_2_prior_kl: 0.0012
# Epoch 58: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.8922 - gp_layer_2_prior_kl: 0.0012
# Epoch 59/200
# 64/64 [==============================] - ETA: 0s - loss: 5.8664 - gp_layer_2_prior_kl: 0.0012
# Epoch 59: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.8664 - gp_layer_2_prior_kl: 0.0012
# Epoch 60/200
# 64/64 [==============================] - ETA: 0s - loss: 5.8413 - gp_layer_2_prior_kl: 0.0012
# Epoch 60: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.8413 - gp_layer_2_prior_kl: 0.0012
# Epoch 61/200
# 64/64 [==============================] - ETA: 0s - loss: 5.8177 - gp_layer_2_prior_kl: 0.0012
# Epoch 61: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.8177 - gp_layer_2_prior_kl: 0.0012
# Epoch 62/200
# 64/64 [==============================] - ETA: 0s - loss: 5.7967 - gp_layer_2_prior_kl: 0.0012
# Epoch 62: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.7967 - gp_layer_2_prior_kl: 0.0012
# Epoch 63/200
# 64/64 [==============================] - ETA: 0s - loss: 5.7752 - gp_layer_2_prior_kl: 0.0012
# Epoch 63: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.7752 - gp_layer_2_prior_kl: 0.0012
# Epoch 64/200
# 64/64 [==============================] - ETA: 0s - loss: 5.7556 - gp_layer_2_prior_kl: 0.0012
# Epoch 64: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.7556 - gp_layer_2_prior_kl: 0.0012
# Epoch 65/200
# 64/64 [==============================] - ETA: 0s - loss: 5.7365 - gp_layer_2_prior_kl: 0.0012
# Epoch 65: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.7365 - gp_layer_2_prior_kl: 0.0012
# Epoch 66/200
# 64/64 [==============================] - ETA: 0s - loss: 5.7178 - gp_layer_2_prior_kl: 0.0012
# Epoch 66: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.7178 - gp_layer_2_prior_kl: 0.0012
# Epoch 67/200
# 64/64 [==============================] - ETA: 0s - loss: 5.7022 - gp_layer_2_prior_kl: 0.0012
# Epoch 67: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.7022 - gp_layer_2_prior_kl: 0.0012
# Epoch 68/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6856 - gp_layer_2_prior_kl: 0.0012
# Epoch 68: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.6856 - gp_layer_2_prior_kl: 0.0012
# Epoch 69/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6702 - gp_layer_2_prior_kl: 0.0012
# Epoch 69: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.6702 - gp_layer_2_prior_kl: 0.0012
# Epoch 70/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6563 - gp_layer_2_prior_kl: 0.0012
# Epoch 70: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.6563 - gp_layer_2_prior_kl: 0.0012
# Epoch 71/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6435 - gp_layer_2_prior_kl: 0.0013
# Epoch 71: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.6435 - gp_layer_2_prior_kl: 0.0013
# Epoch 72/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6302 - gp_layer_2_prior_kl: 0.0013
# Epoch 72: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 269ms/step - loss: 5.6302 - gp_layer_2_prior_kl: 0.0013
# Epoch 73/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6184 - gp_layer_2_prior_kl: 0.0013
# Epoch 73: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.6184 - gp_layer_2_prior_kl: 0.0013
# Epoch 74/200
# 64/64 [==============================] - ETA: 0s - loss: 5.6067 - gp_layer_2_prior_kl: 0.0013
# Epoch 74: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.6067 - gp_layer_2_prior_kl: 0.0013
# Epoch 75/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5962 - gp_layer_2_prior_kl: 0.0013
# Epoch 75: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 269ms/step - loss: 5.5962 - gp_layer_2_prior_kl: 0.0013
# Epoch 76/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5866 - gp_layer_2_prior_kl: 0.0013
# Epoch 76: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5866 - gp_layer_2_prior_kl: 0.0013
# Epoch 77/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5772 - gp_layer_2_prior_kl: 0.0013
# Epoch 77: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5772 - gp_layer_2_prior_kl: 0.0013
# Epoch 78/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5684 - gp_layer_2_prior_kl: 0.0013
# Epoch 78: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5684 - gp_layer_2_prior_kl: 0.0013
# Epoch 79/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5608 - gp_layer_2_prior_kl: 0.0013
# Epoch 79: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.5608 - gp_layer_2_prior_kl: 0.0013
# Epoch 80/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5532 - gp_layer_2_prior_kl: 0.0013
# Epoch 80: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5532 - gp_layer_2_prior_kl: 0.0013
# Epoch 81/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5458 - gp_layer_2_prior_kl: 0.0013
# Epoch 81: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5458 - gp_layer_2_prior_kl: 0.0013
# Epoch 82/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5394 - gp_layer_2_prior_kl: 0.0013
# Epoch 82: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5394 - gp_layer_2_prior_kl: 0.0013
# Epoch 83/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5331 - gp_layer_2_prior_kl: 0.0013
# Epoch 83: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5331 - gp_layer_2_prior_kl: 0.0013
# Epoch 84/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5272 - gp_layer_2_prior_kl: 0.0013
# Epoch 84: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5272 - gp_layer_2_prior_kl: 0.0013
# Epoch 85/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5216 - gp_layer_2_prior_kl: 0.0013
# Epoch 85: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5216 - gp_layer_2_prior_kl: 0.0013
# Epoch 86/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5167 - gp_layer_2_prior_kl: 0.0013
# Epoch 86: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5167 - gp_layer_2_prior_kl: 0.0013
# Epoch 87/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5121 - gp_layer_2_prior_kl: 0.0013
# Epoch 87: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5121 - gp_layer_2_prior_kl: 0.0013
# Epoch 88/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5078 - gp_layer_2_prior_kl: 0.0013
# Epoch 88: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.5078 - gp_layer_2_prior_kl: 0.0013
# Epoch 89/200
# 64/64 [==============================] - ETA: 0s - loss: 5.5034 - gp_layer_2_prior_kl: 0.0014
# Epoch 89: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.5034 - gp_layer_2_prior_kl: 0.0014
# Epoch 90/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4998 - gp_layer_2_prior_kl: 0.0014
# Epoch 90: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.4998 - gp_layer_2_prior_kl: 0.0014
# Epoch 91/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4956 - gp_layer_2_prior_kl: 0.0014
# Epoch 91: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4956 - gp_layer_2_prior_kl: 0.0014
# Epoch 92/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4926 - gp_layer_2_prior_kl: 0.0014
# Epoch 92: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 5.4926 - gp_layer_2_prior_kl: 0.0014
# Epoch 93/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4895 - gp_layer_2_prior_kl: 0.0014
# Epoch 93: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.4895 - gp_layer_2_prior_kl: 0.0014
# Epoch 94/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4867 - gp_layer_2_prior_kl: 0.0014
# Epoch 94: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4867 - gp_layer_2_prior_kl: 0.0014
# Epoch 95/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4831 - gp_layer_2_prior_kl: 0.0014
# Epoch 95: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4831 - gp_layer_2_prior_kl: 0.0014
# Epoch 96/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4792 - gp_layer_2_prior_kl: 0.0014
# Epoch 96: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4792 - gp_layer_2_prior_kl: 0.0014
# Epoch 97/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4746 - gp_layer_2_prior_kl: 0.0015
# Epoch 97: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4746 - gp_layer_2_prior_kl: 0.0015
# Epoch 98/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4689 - gp_layer_2_prior_kl: 0.0015
# Epoch 98: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4689 - gp_layer_2_prior_kl: 0.0015
# Epoch 99/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4602 - gp_layer_2_prior_kl: 0.0016
# Epoch 99: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.4602 - gp_layer_2_prior_kl: 0.0016
# Epoch 100/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4513 - gp_layer_2_prior_kl: 0.0016
# Epoch 100: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4513 - gp_layer_2_prior_kl: 0.0016
# Epoch 101/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4447 - gp_layer_2_prior_kl: 0.0017
# Epoch 101: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 263ms/step - loss: 5.4447 - gp_layer_2_prior_kl: 0.0017
# Epoch 102/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4379 - gp_layer_2_prior_kl: 0.0018
# Epoch 102: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4379 - gp_layer_2_prior_kl: 0.0018
# Epoch 103/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4344 - gp_layer_2_prior_kl: 0.0018
# Epoch 103: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.4344 - gp_layer_2_prior_kl: 0.0018
# Epoch 104/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4314 - gp_layer_2_prior_kl: 0.0018
# Epoch 104: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4314 - gp_layer_2_prior_kl: 0.0018
# Epoch 105/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4295 - gp_layer_2_prior_kl: 0.0018
# Epoch 105: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4295 - gp_layer_2_prior_kl: 0.0018
# Epoch 106/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4272 - gp_layer_2_prior_kl: 0.0019
# Epoch 106: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.4272 - gp_layer_2_prior_kl: 0.0019
# Epoch 107/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4250 - gp_layer_2_prior_kl: 0.0019
# Epoch 107: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.4250 - gp_layer_2_prior_kl: 0.0019
# Epoch 108/200
# 64/64 [==============================] - ETA: 0s - loss: 5.4214 - gp_layer_2_prior_kl: 0.0019
# ...
# 64/64 [==============================] - 17s 267ms/step - loss: 5.3645 - gp_layer_2_prior_kl: 0.0030
# Epoch 164/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3650 - gp_layer_2_prior_kl: 0.0030
# Epoch 164: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3650 - gp_layer_2_prior_kl: 0.0030
# Epoch 165/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3642 - gp_layer_2_prior_kl: 0.0030
# Epoch 165: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3642 - gp_layer_2_prior_kl: 0.0030
# Epoch 166/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3636 - gp_layer_2_prior_kl: 0.0030
# Epoch 166: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3636 - gp_layer_2_prior_kl: 0.0030
# Epoch 167/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3636 - gp_layer_2_prior_kl: 0.0030
# Epoch 167: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3636 - gp_layer_2_prior_kl: 0.0030
# Epoch 168/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3640 - gp_layer_2_prior_kl: 0.0030
# Epoch 168: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3640 - gp_layer_2_prior_kl: 0.0030
# Epoch 169/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3633 - gp_layer_2_prior_kl: 0.0030
# Epoch 169: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3633 - gp_layer_2_prior_kl: 0.0030
# Epoch 170/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3623 - gp_layer_2_prior_kl: 0.0030
# Epoch 170: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3623 - gp_layer_2_prior_kl: 0.0030
# Epoch 171/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3624 - gp_layer_2_prior_kl: 0.0030
# Epoch 171: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3624 - gp_layer_2_prior_kl: 0.0030
# Epoch 172/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3621 - gp_layer_2_prior_kl: 0.0030
# Epoch 172: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.3621 - gp_layer_2_prior_kl: 0.0030
# Epoch 173/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3615 - gp_layer_2_prior_kl: 0.0030
# Epoch 173: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.3615 - gp_layer_2_prior_kl: 0.0030
# Epoch 174/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3615 - gp_layer_2_prior_kl: 0.0030
# Epoch 174: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3615 - gp_layer_2_prior_kl: 0.0030
# Epoch 175/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3618 - gp_layer_2_prior_kl: 0.0030
# Epoch 175: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3618 - gp_layer_2_prior_kl: 0.0030
# Epoch 176/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3615 - gp_layer_2_prior_kl: 0.0030
# Epoch 176: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3615 - gp_layer_2_prior_kl: 0.0030
# Epoch 177/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3609 - gp_layer_2_prior_kl: 0.0030
# Epoch 177: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.3609 - gp_layer_2_prior_kl: 0.0030
# Epoch 178/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3612 - gp_layer_2_prior_kl: 0.0030
# Epoch 178: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3612 - gp_layer_2_prior_kl: 0.0030
# Epoch 179/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3609 - gp_layer_2_prior_kl: 0.0030
# Epoch 179: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3609 - gp_layer_2_prior_kl: 0.0030
# Epoch 180/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3605 - gp_layer_2_prior_kl: 0.0030
# Epoch 180: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3605 - gp_layer_2_prior_kl: 0.0030
# Epoch 181/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3605 - gp_layer_2_prior_kl: 0.0030
# Epoch 181: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3605 - gp_layer_2_prior_kl: 0.0030
# Epoch 182/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3601 - gp_layer_2_prior_kl: 0.0030
# Epoch 182: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 268ms/step - loss: 5.3601 - gp_layer_2_prior_kl: 0.0030
# Epoch 183/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3608 - gp_layer_2_prior_kl: 0.0030
# Epoch 183: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.3608 - gp_layer_2_prior_kl: 0.0030
# Epoch 184/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3602 - gp_layer_2_prior_kl: 0.0030
# Epoch 184: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3602 - gp_layer_2_prior_kl: 0.0030
# Epoch 185/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3604 - gp_layer_2_prior_kl: 0.0030
# Epoch 185: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3604 - gp_layer_2_prior_kl: 0.0030
# Epoch 186/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3599 - gp_layer_2_prior_kl: 0.0030
# Epoch 186: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3599 - gp_layer_2_prior_kl: 0.0030
# Epoch 187/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3599 - gp_layer_2_prior_kl: 0.0030
# Epoch 187: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3599 - gp_layer_2_prior_kl: 0.0030
# Epoch 188/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3592 - gp_layer_2_prior_kl: 0.0030
# Epoch 188: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3592 - gp_layer_2_prior_kl: 0.0030
# Epoch 189/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3595 - gp_layer_2_prior_kl: 0.0030
# Epoch 189: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 267ms/step - loss: 5.3595 - gp_layer_2_prior_kl: 0.0030
# Epoch 190/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3594 - gp_layer_2_prior_kl: 0.0030
# Epoch 190: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3594 - gp_layer_2_prior_kl: 0.0030
# Epoch 191/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3594 - gp_layer_2_prior_kl: 0.0030
# Epoch 191: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3594 - gp_layer_2_prior_kl: 0.0030
# Epoch 192/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3595 - gp_layer_2_prior_kl: 0.0030
# Epoch 192: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 266ms/step - loss: 5.3595 - gp_layer_2_prior_kl: 0.0030
# Epoch 193/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3597 - gp_layer_2_prior_kl: 0.0031
# Epoch 193: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3597 - gp_layer_2_prior_kl: 0.0031
# Epoch 194/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3592 - gp_layer_2_prior_kl: 0.0031
# Epoch 194: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.3592 - gp_layer_2_prior_kl: 0.0031
# Epoch 195/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3593 - gp_layer_2_prior_kl: 0.0031
# Epoch 195: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3593 - gp_layer_2_prior_kl: 0.0031
# Epoch 196/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3588 - gp_layer_2_prior_kl: 0.0031
# Epoch 196: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3588 - gp_layer_2_prior_kl: 0.0031
# Epoch 197/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3586 - gp_layer_2_prior_kl: 0.0031
# Epoch 197: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.3586 - gp_layer_2_prior_kl: 0.0031
# Epoch 198/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3585 - gp_layer_2_prior_kl: 0.0031
# Epoch 198: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 265ms/step - loss: 5.3585 - gp_layer_2_prior_kl: 0.0031
# Epoch 199/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3583 - gp_layer_2_prior_kl: 0.0031
# Epoch 199: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.3583 - gp_layer_2_prior_kl: 0.0031
# Epoch 200/200
# 64/64 [==============================] - ETA: 0s - loss: 5.3583 - gp_layer_2_prior_kl: 0.0031
# Epoch 200: saving model to ./RunningPBMC5KCITEseqRNA-GPFlux cells=800  genes=800  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=200  emb_reg=0.001 with_PCA=0/model_params.ckpt
# 64/64 [==============================] - 17s 264ms/step - loss: 5.3583 - gp_layer_2_prior_kl: 0.0031

# %%
dim1 = 2
dim2 = 2
dim3 = 2
num_epochs = 200
n_inducing_points1 = 512
n_inducing_points2 = 512
batch_size = 10000
with_PCA = 0
with_PPCA = 0
scale_emb1 = 0
scale_emb2 = 0
emb_reg = 0.001
lr = float(0.01)
kernel = ["RBF"]
if (with_PCA==0 or with_PPCA==0):
    title = 'cells='+str(num_rows)+'  genes='+str(num_cols)+'  dim1='+str(dim1)+'  dim2='+str(dim2)+'  dim3='+str(dim3)+'  InducingPoints1='+str(n_inducing_points1)+'  InducingPoints2='+str(n_inducing_points2)+'  BatchSize='+str(batch_size)+'  epochs='+str(num_epochs)+'  emb_reg='+str(emb_reg)+ ' with_PCA='+str(with_PCA)
    save_path = './RunningPBMC5KCITEseqRNA-GPFlux '+title+'/' 
    #save_path='./PBMC5KCITEseq2View-GPFlux  dim1=2  dim2=2  dim3=2  InducingPoints1=512  InducingPoints2=512  BatchSize=10000  epochs=500  emb_reg=0.001 with_PCA=0'
    hyper_params = {
    'I':I,
    'J':J,
    'K':None,    # the number of entities in each domain
    'M1': n_inducing_points1,                  # the number of inducing pairs
    'M2': n_inducing_points2,                  # the number of inducing pairs
    'emb_sizes': [dim1,dim2,dim3],      # the embedding sizes
    'batch_size':batch_size,      # the size of training batches
    'obs_mean1': Y_tr1.mean(),  # the mean of target
    'obs_mean2': None,  # the mean of target
    'emb_reg': emb_reg,          # l2 norm on the embeddings
    'lr': lr,                # the learning rate 
    'save_path': save_path,        # path to save the trained models.
    }  
    
    gp_md = GPD(**hyper_params)
    gp_md.build(kernels=kernel)
    gp_md.load_model((X_tr1+1), None)
    
    emb1 = gp_md.emb1
    embs1 = emb1((X_tr1+1)[0:-1:J,0])
    
    emb2 = gp_md.emb2
    embs2 = emb2((X_tr1+1)[0:J,1])
    
    RNA_struct_MOGP = ad.AnnData(embs1.numpy())
    RNA_struct_MOGP.obsm['X_tsne']= embs1.numpy()
    
    Genes_struct_MOGP = ad.AnnData(embs2.numpy())
    Genes_struct_MOGP.obsm['X_tsne']= embs2.numpy()
    
    RNA_struct_sampled = ad.AnnData(rna.X[row_indices,:][:,col_indices])
    RNA_struct_sampled.var_names=rna.var_names[col_indices]
    RNA_struct_sampled.obs_names=rna.obs_names[row_indices]
    RNA_struct_sampled.obs["celltype"]=rna.obs["celltype"][row_indices]
    RNA_struct_sampled.uns["rank_genes_groups"]=rna.uns["rank_genes_groups"]
    
    Relating_clusters_of_emb1_to_clusters_of_emb2_CITEseq(RNA_struct_sampled, None, RNA_struct_MOGP, Genes_struct_MOGP, Prot_struct_MOGP=None, col_dict1=col_dict1, cell_type_list_modified1=cell_type_list_modified1, cell_type_list_modified2=cell_type_list_modified2, n_cell_types=len(list(set(rna.obs["celltype"]))),n_marker_genes=100, use_umap=False)
